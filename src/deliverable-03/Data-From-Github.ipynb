# %%
import numpy as np
import pandas as pd
import requests
from io import StringIO

def download_and_combine_csv(urls: list) -> pd.DataFrame:
    """
    Download CSV files from provided URLs and combine them row-wise.
    It will combine files if they have the expected column names or just the correct number of columns.
    Handles different encodings to avoid common decoding errors. Converts certain columns to integer form.

    Args:
    urls (list): List of strings containing the URLs of the CSV files.

    Returns:
    pd.DataFrame: A DataFrame containing the combined data from all matching CSV files.
    """
    expected_columns = {'user_prompt', 'url_to_check', 'func_rating', 'custom_rating'}
    combined_df = pd.DataFrame()

    for url in urls:
        try:
            # Modify the GitHub URL to point to the raw version of the file
            raw_url = url.replace('github.com', 'raw.githubusercontent.com').replace('/blob', '')

            response = requests.get(raw_url)
            if response.status_code == 200:
                try:
                    # Attempt to read with utf-8 encoding
                    content = response.content.decode('utf-8')
                except UnicodeDecodeError:
                    # Attempt to read with latin1 encoding
                    content = response.content.decode('latin1')

                # Read the CSV file into a DataFrame
                df = pd.read_csv(StringIO(content))
                
                # Round numeric columns to nearest integers and convert to int data type
                for c in df.select_dtypes(include = np.number).columns.tolist():
                    df[c] = df[c].map(lambda x: np.round(x)).fillna(0).astype(int)

                # Check if the columns match the expected columns or if there are at least 4 columns
                if set(df.columns) == expected_columns:
                    combined_df = pd.concat([combined_df, df], ignore_index=True)
                elif len(df.columns) >= 4:
                    # Assume the first 4 columns are the required ones and ignore the original column names
                    df = df.iloc[:, :4]
                    df.columns = ['user_prompt', 'url_to_check', 'func_rating', 'custom_rating']
                    combined_df = pd.concat([combined_df, df], ignore_index=True)
                else:
                    print(f"Skipping file with insufficient columns: {url}")
            else:
                print(f"Failed to download from {url}")
        except Exception as e:
            print(f"Error processing {url}: {str(e)}")

    # Ensure func_rating and custom_rating are integers
    if not combined_df.empty:
        combined_df['func_rating'] = combined_df['func_rating'].round().astype(int)
        combined_df['custom_rating'] = combined_df['custom_rating'].round().astype(int)

    return combined_df

# %%
urls = [
    "https://github.com/vrutika-prajapati/Credibility-Score-for-Articles/blob/main/projects/deliverable%202/Url_validation.csv",
    "https://github.com/Saikumar08-sk/URL-Validation/blob/main/Deliverable.csv",
    "https://github.com/aditya19111/Project-1-Credibility-Score-for-Articles-Sources-References/blob/main/Deliverable_2/Deliverables_rating_comparison%20-%20Sheet1.csv",
    "https://github.com/SAIKUMAR500/algorithums-for-data-science/blob/main/deliverable2/dataset(Sheet1).csv",
    "https://github.com/drashti-sanghani/Credibility_score_articles/blob/main/Project/Deliverable2/user_ratings.csv",
    "https://github.com/anchalrai101/CREDIBILITY-SCORE/blob/main/urltesting_scores.csv",
    "https://github.com/AliSInamdar/CS676-Ali-Inamdar/blob/Project_1_Credibilty_Score/Deliverable_2/Deliverable_2.csv",
    "https://github.com/bhavnaa22/Algorithms-For-Data-Science/blob/main/Deliverable%202/Deliverable2.csv",
    "https://github.com/bhatthardik4/AlgorithmDS/blob/main/Deliverable_2/HardikBhattD2.csv",
    "https://github.com/Rakeshkanche/Algorithms-for-Data-Science/blob/main/queries_urls_ratings.csv",
    "https://github.com/kristinakim-code/Credibility-Check/blob/main/deliverable2.csv",
    "https://github.com/bhavnaa22/Algorithms-For-Data-Science/blob/main/Deliverable%202/Deliverable2.csv",
    "https://github.com/kamaldomandula/Algorithms-of-data-science-Project/blob/main/Project/project1/Deliverable2/deliverable.csv",
    "https://github.com/ChinmayShetye26/Algo-for-DS-delivery2/blob/main/Sample.csv",
    "https://github.com/krishnam229/Project1/blob/main/deliverable2/sample.csv",
    "https://github.com/drona23/Deliverable2/blob/main/output.csv",
    "https://github.com/JoshuaGottlieb/Chatbot-Credibility-Scorer/blob/main/src/deliverable-02/testing/sample.csv"
]

# %%
result_df = download_and_combine_csv(urls)
result_df
# Out:
#                                            user_prompt  \
# 0    I have just been on an international flight, c...
# 1          What are the benefits of a vegetarian diet?
# 2          What are the benefits of a vegetarian diet?
# 3          What are the benefits of a vegetarian diet?
# 4    How to improve mental health during stressful ...
# ..                                                 ...
# 297  How does altitude training affect endurance in...
# 298  What are the safest travel destinations for so...
# 299  How can travelers find sustainable and eco-fri...
# 300  What cultural experiences should not be missed...
# 301  How do budget travel options compare to luxury...
#
#                                           url_to_check  func_rating  \
# 0    https://www.mayoclinic.org/healthy-lifestyle/i...            2
# 1    https://www.nhs.uk/live-well/eat-well/how-to-e...            2
# 2    https://www.nhs.uk/live-well/eat-well/how-to-e...            2
# 3    https://pubmed.ncbi.nlm.nih.gov/37226630/#:~:t...            2
# 4    https://www.who.int/news-room/questions-and-an...            3
# ..                                                 ...          ...
# 297  https://sports.stackexchange.com/questions/498...            3
# 298  https://www.exploreworldwide.com/blog/top-solo...            3
# 299  https://www.peekpro.com/blog/sustainable-touri...            3
# 300  https://www.insidejapantours.com/blog/2015/08/...            2
# 301  https://traveltillyoudrop.com/budget-travel-vs...            3
#
#      custom_rating
# 0                3
# 1                4
# 2                2
# 3                3
# 4                3
# ..             ...
# 297              3
# 298              2
# 299              3
# 300              4
# 301              4
#
# [302 rows x 4 columns]

# %%
result_df.to_csv('prompts_and_ratings.csv', index = False)

# %%
result_df.user_prompt.unique()
# Out:
# array(['I have just been on an international flight, can I come back home to hold my 1-month-old newborn?',
#        'What are the benefits of a vegetarian diet?',
#        'How to improve mental health during stressful times?',
#        'What are the dangers of smoking?',
#        'How does exercise impact your health?', 'what is AI',
#        'How does climate change impact global weather?',
#        'What are the latest advancements in AI?',
#        'How does diet influence mental health?',
#        'What are the effects of space travel on astronauts?',
#        'Is cryptocurrency a safe investment?',
#        'What are the advantages of renewable energy?',
#        'How does deep learning work?',
#        'What are the health risks of 5G technology?',
#        'Is intermittent fasting effective for weight loss?',
#        'How do electric vehicles compare to gas cars?',
#        'What are the symptoms of the flu?',
#        'How does quantum computing work?',
#        'What is the impact of social media on mental health?',
#        'Are genetically modified foods safe?',
#        'What are the benefits of mindfulness meditation?',
#        'Nvidias rtx 5070 new gpu is it really good ?',
#        'kingdome come deliverance 2 got good rating compare to one give me a proper review about this game',
#        'delta airlines planes crashed in toronto airport give me some relevant news regarding it',
#        'deep learning sleep algorithm details and its working',
#        'was moon landing by NASA fake!',
#        'does whey protein deteriorate kidney function',
#        'will amd FSR get better than nvidia dlss 4',
#        'How will AI impact the job market in the next 10 years?',
#        'What are the ethical challenges of AI-driven decision-making in healthcare?',
#        'Can artificial intelligence develop emotions similar to humans?',
#        'What are the latest discoveries in space exploration that could change our understanding of the universe?',
#        '"What role does neuroscience play in developing artificial consciousness?',
#        'Can genetic engineering help humans evolve beyond biological limitations?',
#        'If human consciousness could be uploaded to a machine, would it still be \x91you\x92?',
#        'What are the psychological effects of living in a fully virtual world (metaverse)?',
#        'How will automation impact wealth distribution and economic inequality?',
#        'How can companies integrate AI responsibly into their business operations?',
#        'What are the key traits that make an entrepreneur successful in 2025?',
#        'What are the challenges and possibilities of colonizing Mars?',
#        'How will climate change impact global migration patterns in the next 50 years?',
#        'What are the biggest ethical concerns surrounding AI surveillance?',
#        'What are the symptoms of depression?',
#        'Is it safe to travel during a pandemic?',
#        'How can I boost my immune system naturally?',
#        'How do I learn to code in Python?',
#        'AI-powered predictive analytics is revolutionizing industries by enabling businesses to anticipate future trends and customer behavior.',
#        'Data science is becoming increasingly interdisciplinary, drawing on expertise from fields like statistics, computer science, and domain-specific knowledge.',
#        'The use of social media and AI-driven bots in political campaigns raises concerns about the spread of misinformation and propaganda.',
#        'Virtual reality and augmented reality are transforming the way we interact with technology and experience the world.',
#        'Blockchain technology has the potential to revolutionize industries by providing secure and transparent record-keeping.',
#        'Quantum computing is a nascent technology that could potentially revolutionize computing by solving problems that are currently intractable for classical computers.',
#        'The universe is vast and mostly empty, a cosmic ocean dotted with islands of matter.',
#        'Climate change is causing a rise in global temperatures, leading to more frequent and intense extreme weather events.',
#        'The development of new antibiotics is struggling to keep pace with the growing problem of antibiotic resistance.',
#        'The exploration of space continues to inspire scientific discovery and expand our understanding of the universe.',
#        'Artificial intelligence has the potential to automate many tasks currently performed by humans, leading to increased productivity but also potential job displacement.',
#        'What are the latest updates on global politics?',
#        'Can Wikipedia be trusted for academic research?',
#        'What are the most trending topics in technology today?',
#        'What is the impact of artificial intelligence on jobs?',
#        'How does climate change affect global weather patterns?',
#        'What are the latest scientific breakthroughs in medicine?',
#        'What are the official symptoms of COVID-19?',
#        'How can I improve my writing skills for blogging?',
#        'What are the benefits of publishing research on ResearchGate?',
#        'What are the key financial trends to watch for this year?',
#        "What is NASA's latest mission in space exploration?",
#        'Are vaccines safe for children according to WHO?',
#        'Spine Surgery', 'Nvidia Stock Price', 'Bitcoin Price',
#        'Best stock to buy',
#        'which is the best sip to invest for long term',
#        'is mutual funds safe', 'how to make safe investments',
#        'What is artificial intelligence?',
#        'How does blockchain technology work?',
#        'What is the significance of the Great Wall of China?',
#        'What causes global warming?',
#        'How do vaccines help prevent disease?',
#        'What is the history of the Internet?',
#        'What are the risks of smoking?',
#        'What is the process of photosynthesis?',
#        'What are the economic impacts of COVID-19?',
#        'How do electric cars work?',
#        'What are the effects of climate change?',
#        'I have just been on an international flight',
#        '"I recently tested positive for COVID-19. How long should I wait before traveling internationally?"',
#        '"At what age should my baby get their first set of vaccinations?"',
#        '"What are some recommended foods for managing type 2 diabetes?"',
#        '"Can I bring a carry-on suitcase and a personal item on a Delta flight?"',
#        '"What are some common behavioral interview questions and how should I answer them?"',
#        '"Is it safe to do strength training exercises during pregnancy?"',
#        '"What are the common side effects of taking ibuprofen?"',
#        '"What are the requirements for applying for a student visa in Canada?"',
#        '"What are the steps to getting approved for a mortgage?"',
#        '"What are the best beginner-friendly resources for learning Python programming?"',
#        'Latest advancements in AI', 'Climate change effects',
#        'Stock market trends', 'Healthy diet tips',
#        'Best programming languages', 'Space exploration updates',
#        'Cybersecurity threats', 'Electric vehicle advancements',
#        'Blockchain technology', 'Mental health awareness',
#        'What are the symptoms of COVID-19?',
#        'How effective is the flu vaccine this year?',
#        'What are the causes of global warming?',
#        'How does exercise affect mental health?',
#        'What are the benefits of meditation?', 'How do vaccines work?',
#        'What are the side effects of the COVID-19 vaccine?',
#        'How to reduce stress at work?',
#        'What are the signs of depression?',
#        'How to prevent heart disease?', 'What is quantum computing?',
#        'What is the best diet for weight loss?',
#        'How does climate change affect wildlife?',
#        'What are the symptoms of anxiety?',
#        'How to improve sleep quality?',
#        'What is the difference between Type 1 and Type 2 diabetes?',
#        'How to manage time effectively?',
#        'What is the impact of social media on teenagers?',
#        'How to prepare for a job interview?',
#        'How to bake a chocolate cake?', 'Best exercises for weight loss?',
#        'Tell me about the benefits of meditation.',
#        'What are the symptoms of flu?',
#        'Explain the theory of relativity in simple terms.',
#        'What are the latest trends in AI?',
#        'What are some beginner-friendly programming languages?',
#        'Tell me about the history of Ancient Rome.',
#        'Difference between AI/ML',
#        'Evaluate the effectiveness of COP28 resolutions on global carbon emissions.',
#        'Analyze the recent fluctuations in the cryptocurrency market following regulatory changes in the U.S. and Europe.',
#        'Investigate the global impact of the latest WHO advisory on new COVID-19 variants.',
#        'the significance of the latest lunar exploration missions by NASA and ISRO. Discuss how these missions impact global space policies and international collaborations in space exploration.',
#        'With the recent surge in deepfake scams and AI-generated fraud, assess the role of cybersecurity frameworks in protecting user data.',
#        "Analyze the significance of the Baltic states synchronizing their power grids with continental Europe, disconnecting from Russia's grid.",
#        'Investigate the surge in private school enrollments in Australia over the past five years.',
#        "Evaluate the approval of a weight loss drug for heart disease treatment by Australia's medicines regulator.",
#        'What are the benefits of drinking green tea?',
#        'How can I improve my sleep quality?',
#        'How do I prevent heart disease?',
#        'What are the side effects of too much caffeine?',
#        'How does meditation help with stress?',
#        'What is the importance of hydration?',
#        'What should I eat for a healthy breakfast?',
#        'What are some effective time management techniques?',
#        'What are the causes of back pain?',
#        'How can I boost my immune system?',
#        'What are the benefits of yoga?',
#        'How does alcohol affect the body?',
#        'What are the different types of depression?',
#        'How can I reduce my risk of diabetes?',
#        'What is the role of fiber in digestion?',
#        'How do I manage anxiety?', 'How do I know if I’m dehydrated?',
#        'What is the importance of exercise?', 'What is a balanced diet?',
#        'What is a healthy body weight?',
#        'What is a healthy sleep routine?', 'How do I improve my memory?',
#        'What are the benefits of a plant-based diet?',
#        'What are the symptoms of vitamin D deficiency?',
#        'How does stress affect the body?',
#        'What are some healthy ways to cope with stress?',
#        'What are some common causes of headaches?',
#        'What is intermittent fasting?',
#        'What are the best exercises for weight loss?',
#        'How does smoking affect lung health?',
#        'What is the difference between LDL and HDL cholesterol?',
#        'What is a healthy heart rate?',
#        'How do I reduce my sugar intake?', 'What is a keto diet?',
#        'What are the risks of high blood pressure?',
#        'How can I improve my digestion?',
#        'What is the role of antioxidants in the body?',
#        'How do I control my blood sugar?',
#        'What is the best way to stay motivated?',
#        'How can I stay productive working from home?',
#        'What are the signs of burnout?',
#        'How do I manage my time effectively?', 'What is mindfulness?',
#        'How do I improve my self-esteem?', 'How do I handle failure?',
#        'What are the benefits of journaling?',
#        'What is the difference between introverts and extroverts?',
#        'How can I develop a growth mindset?',
#        'What are the benefits of gratitude?', 'What is self-care?',
#        'How do I stay positive?', 'How do I know if I am an empath?',
#        'What is social anxiety?', 'How do I overcome procrastination?',
#        'What is the best way to study?',
#        'How do I set goals effectively?', 'What is self-discipline?',
#        'What is the importance of forgiveness?',
#        'How do I deal with anxiety attacks?',
#        'How do I improve my communication skills?',
#        'What is assertiveness?', 'What is emotional intelligence?',
#        'How do I build resilience?', 'How do I overcome perfectionism?',
#        'What is the importance of sleep?',
#        'What are some healthy habits?',
#        'How can I build self-confidence?',
#        'What are the benefits of volunteering?',
#        'What is the importance of good posture?',
#        'How do I get better at public speaking?',
#        'What is the importance of self-reflection?',
#        'How can I find a good therapist?',
#        'How can I manage my finances?', 'How do I deal with rejection?',
#        'What is the importance of mindfulness?',
#        'What are the symptoms of ADHD?',
#        'How do I deal with difficult people?',
#        'What is the importance of empathy?',
#        'How do I find purpose in life?', 'How do I set boundaries?',
#        'How do I improve my work-life balance?',
#        'What is emotional abuse?', 'How do I build a positive mindset?',
#        'What is the difference between sympathy and empathy?',
#        'How do I stop negative thinking?',
#        'What are the benefits of a morning routine?',
#        'What is self-sabotage?', 'How can I cope with change?',
#        'What is the importance of goal-setting?',
#        'How can I deal with negative emotions?',
#        'COVID-19 vaccine effectiveness', 'Latest AI advancements',
#        'Space exploration missions', 'Electric vehicle benefits',
#        'History of the internet', 'Python programming tutorials',
#        'What are the top emerging markets for long-term investment strategies?',
#        'How can I diversify my portfolio to minimize financial risk?',
#        'What impact do interest rate changes have on personal savings plans?',
#        'How do economic indicators influence global stock market trends?',
#        'What are the benefits of regular exercise on mental well-being?',
#        'How can mindfulness meditation reduce stress and improve overall health?',
#        'What are the best exercises to improve heart health for beginners?',
#        'How does sleep quality affect physical and mental health outcomes?',
#        'What are the latest advancements in personalized cancer treatment therapies?',
#        'How do gene therapies work in curing rare genetic disorders?',
#        'What are the side effects of the new migraine medication compared to older drugs?',
#        'How is telemedicine changing patient care in rural communities?',
#        'What training techniques are most effective for improving marathon performance?',
#        'How has data analytics transformed professional basketball strategies?',
#        'What are the benefits of cross-training for injury prevention in athletes?',
#        'How does altitude training affect endurance in competitive sports events?',
#        'What are the safest travel destinations for solo travelers in 2025?',
#        'How can travelers find sustainable and eco-friendly vacation options?',
#        'What cultural experiences should not be missed in Japan’s rural areas?',
#        'How do budget travel options compare to luxury travel experiences worldwide?'],
#       dtype=object)
